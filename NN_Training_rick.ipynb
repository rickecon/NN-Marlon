# %% [markdown]
# This notebook builds a surrogate model for the macroeconomic impacts of improvements in biological aging.
#
# To run this notebooks, use the `dynviz-dev` virtual environment, which can be build using the `environment.yml` file located in the same directory as this notebook.
#
# # Imports

# %%
# imports
import numpy as np
import os
import pandas as pd
import scipy.interpolate as si
import pickle
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import tensorflow_decision_forests as tfdf
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1. Prep the data
# The following data contains 1 predicted variable $y$ which is an $N\times 1$ vector and one matrix of 6 input variables $X$ which is an $N\times 6$ matrix, where $N=27,472$.

# %%
# Set the current directory as the cur_dir path
cur_dir = os.getcwd()

# Read in the data
X = np.loadtxt('X.txt', delimiter=',')
y = np.loadtxt('y.txt', delimiter=',').reshape(-1, 1)
print(f"The shape of X is {X.shape}")
print(f"The shape of y is {y.shape}")
# Out:
# The shape of X is (27472, 6)
# The shape of y is (27472, 1)

# %%
# train-test split for model evaluation
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.8, shuffle=True
)

# %% [markdown]
# Here is the linear N-dimensional interpolant that we fit to our sparse runs of 472 data points in this $(X,y)$ space. This interpolant `interpolant_avg_diff()` is an estimated `scipy.interpolate.LinearNDInterpolator` object. This would be useful, e.g., if you want to use the surrogate model to generate new data points for each epoch.

# %%
interpolant_avg_diff = pickle.load(
    open(
        os.path.join(cur_dir, "interpolant_avg_diff.pkl"), "rb"
    )
)
# using
prediction = interpolant_avg_diff(X_test)
print("Predictions = ", prediction[:5])
# Out:
# /var/folders/d4/trj3dssd6s3g8kxvjmczz11w0000gn/T/ipykernel_48554/766540044.py:1: DeprecationWarning: Please import `LinearNDInterpolator` from the `scipy.interpolate` namespace; the `scipy.interpolate.interpnd` namespace is deprecated and will be removed in SciPy 2.0.0.
#   interpolant_avg_diff = pickle.load(
# Predictions =  [[1583.98631597]
#  [1096.02258165]
#  [2346.84653459]
#  [1716.46402266]
#  [1382.78705826]]

# %% [markdown]
# # Set up the NN model

# %%
# set some hyperparameters
nodes_per_layer = 20 # multiplied by num inputs
activation_function = "relu"
num_epochs = 100
learning_rate = 0.001
# set up early stopping
callback = keras.callbacks.EarlyStopping(
    monitor='loss', patience=5000
    )

# %%
# Layer setting
num_input = X.shape[1]
num_hidden_layers = 7
num_hidden = np.zeros(num_hidden_layers)
# Start with more nodes per layer and decrease
for i in range(num_hidden_layers):
    num_hidden[i] = (nodes_per_layer - i * 2) * num_input
# num_hidden = nodes_per_layer * num_input
num_output = y.shape[1]
layers_dim = [num_input, num_hidden, num_output]
print("Dimensions of each layer are {}".format(layers_dim))
# Out:
# Dimensions of each layer are [6, array([120., 108.,  96.,  84.,  72.,  60.,  48.]), 1]

# %%
# Define the normalization function of the output
def normalize_output(data):
    data_max = np.max(data)
    data_min = np.min(data)
    return (data - data_min) / (data_max - data_min)

# %%
# Create a normalization layer for the inputs
norm_layer = tf.keras.layers.Normalization(input_shape=[num_input,], axis=-1)
# norm_layer = tf.keras.layers.Normalization(input_shape=[num_input,], axis=None)

# Initialize the weights
initializer = tf.keras.initializers.HeNormal()
# initializer = tf.keras.initializers.HeUniform()

# Adapt the layer to your training data
norm_layer.adapt(X_train)
nn = tf.keras.Sequential(
    [
        norm_layer,
        keras.layers.Dense(num_hidden[0], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[1], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[2], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[3], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[4], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[5], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[6], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_output, kernel_initializer=initializer),
    ]
)
print(nn.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 6)                 13
#  on)
#
#  dense (Dense)               (None, 120)               840
#
#  dense_1 (Dense)             (None, 108)               13068
#
#  dense_2 (Dense)             (None, 96)                10464
#
#  dense_3 (Dense)             (None, 84)                8148
#
#  dense_4 (Dense)             (None, 72)                6120
#
#  dense_5 (Dense)             (None, 60)                4380
#
#  dense_6 (Dense)             (None, 48)                2928
#
#  dense_7 (Dense)             (None, 1)                 49
#
# =================================================================
# Total params: 46010 (179.73 KB)
# Trainable params: 45997 (179.68 KB)
# Non-trainable params: 13 (56.00 Byte)
# _________________________________________________________________
# None
# /opt/anaconda3/envs/dynviz-dev/lib/python3.11/site-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(

# %%
loss_fn = tf.keras.losses.MeanSquaredError()
optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
nn.compile(optimizer=optimizer, loss=loss_fn, metrics=['mean_squared_error'])

# %% [markdown]
# Train the model.

# %%
history = nn.fit(
    X_train, normalize_output(y_train),
    epochs=num_epochs,
    callbacks=[callback],
    # sample_weight=sample_weights,
    batch_size=32,
    validation_data=(X_test,  normalize_output(y_test)),
    validation_freq=5,   # Evaluate every 5 epochs
    verbose=1
)
# Out:
# Epoch 1/100
# 687/687 [==============================] - 1s 1ms/step - loss: 0.0224 - mean_squared_error: 0.0224
# Epoch 2/100
# 687/687 [==============================] - 1s 1ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 3/100
# 687/687 [==============================] - 1s 1ms/step - loss: 8.8087e-04 - mean_squared_error: 8.8087e-04
# Epoch 4/100
# 687/687 [==============================] - 1s 1ms/step - loss: 6.3593e-04 - mean_squared_error: 6.3593e-04
# Epoch 5/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.8884e-04 - mean_squared_error: 4.8884e-04 - val_loss: 5.5437e-04 - val_mean_squared_error: 5.5437e-04
# Epoch 6/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.8819e-04 - mean_squared_error: 3.8819e-04
# Epoch 7/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.3440e-04 - mean_squared_error: 3.3440e-04
# Epoch 8/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.3090e-04 - mean_squared_error: 3.3090e-04
# Epoch 9/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.5577e-04 - mean_squared_error: 2.5577e-04
# Epoch 10/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.0776e-04 - mean_squared_error: 2.0776e-04 - val_loss: 4.8568e-04 - val_mean_squared_error: 4.8568e-04
# Epoch 11/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.8635e-04 - mean_squared_error: 1.8635e-04
# Epoch 12/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.7693e-04 - mean_squared_error: 1.7693e-04
# Epoch 13/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.6183e-04 - mean_squared_error: 1.6183e-04
# Epoch 14/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.3979e-04 - mean_squared_error: 1.3979e-04
# Epoch 15/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.4486e-04 - mean_squared_error: 1.4486e-04 - val_loss: 1.6855e-04 - val_mean_squared_error: 1.6855e-04
# Epoch 16/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.1477e-04 - mean_squared_error: 1.1477e-04
# Epoch 17/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.2699e-04 - mean_squared_error: 1.2699e-04
# Epoch 18/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.0583e-04 - mean_squared_error: 1.0583e-04
# Epoch 19/100
# 687/687 [==============================] - 1s 1ms/step - loss: 9.7302e-05 - mean_squared_error: 9.7302e-05
# Epoch 20/100
# 687/687 [==============================] - 1s 1ms/step - loss: 9.2128e-05 - mean_squared_error: 9.2128e-05 - val_loss: 1.5264e-04 - val_mean_squared_error: 1.5264e-04
# Epoch 21/100
# 687/687 [==============================] - 1s 1ms/step - loss: 9.0994e-05 - mean_squared_error: 9.0994e-05
# Epoch 22/100
# 687/687 [==============================] - 1s 1ms/step - loss: 8.3079e-05 - mean_squared_error: 8.3079e-05
# Epoch 23/100
# 687/687 [==============================] - 1s 1ms/step - loss: 8.2021e-05 - mean_squared_error: 8.2021e-05
# Epoch 24/100
# 687/687 [==============================] - 1s 1ms/step - loss: 8.1413e-05 - mean_squared_error: 8.1413e-05
# Epoch 25/100
# 687/687 [==============================] - 1s 1ms/step - loss: 7.8965e-05 - mean_squared_error: 7.8965e-05 - val_loss: 2.5002e-04 - val_mean_squared_error: 2.5002e-04
# Epoch 26/100
# 687/687 [==============================] - 1s 1ms/step - loss: 6.5819e-05 - mean_squared_error: 6.5819e-05
# Epoch 27/100
# 687/687 [==============================] - 1s 1ms/step - loss: 7.6874e-05 - mean_squared_error: 7.6874e-05
# Epoch 28/100
# 687/687 [==============================] - 1s 1ms/step - loss: 6.6295e-05 - mean_squared_error: 6.6295e-05
# Epoch 29/100
# 687/687 [==============================] - 1s 1ms/step - loss: 6.6656e-05 - mean_squared_error: 6.6656e-05
# Epoch 30/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.6245e-05 - mean_squared_error: 5.6245e-05 - val_loss: 1.8672e-04 - val_mean_squared_error: 1.8672e-04
# Epoch 31/100
# 687/687 [==============================] - 1s 1ms/step - loss: 6.1842e-05 - mean_squared_error: 6.1842e-05
# Epoch 32/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.8413e-05 - mean_squared_error: 5.8413e-05
# Epoch 33/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.5803e-05 - mean_squared_error: 5.5803e-05
# Epoch 34/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.3395e-05 - mean_squared_error: 5.3395e-05
# Epoch 35/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.9209e-05 - mean_squared_error: 4.9209e-05 - val_loss: 1.8980e-04 - val_mean_squared_error: 1.8980e-04
# Epoch 36/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.1817e-05 - mean_squared_error: 5.1817e-05
# Epoch 37/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.9767e-05 - mean_squared_error: 4.9767e-05
# Epoch 38/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.5290e-05 - mean_squared_error: 4.5290e-05
# Epoch 39/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.5091e-05 - mean_squared_error: 4.5091e-05
# Epoch 40/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.7251e-05 - mean_squared_error: 4.7251e-05 - val_loss: 2.2104e-04 - val_mean_squared_error: 2.2104e-04
# Epoch 41/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.1577e-05 - mean_squared_error: 4.1577e-05
# Epoch 42/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.5409e-05 - mean_squared_error: 4.5409e-05
# Epoch 43/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.5899e-05 - mean_squared_error: 4.5899e-05
# Epoch 44/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.9492e-05 - mean_squared_error: 3.9492e-05
# Epoch 45/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.3080e-05 - mean_squared_error: 4.3080e-05 - val_loss: 2.1738e-04 - val_mean_squared_error: 2.1738e-04
# Epoch 46/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.1295e-05 - mean_squared_error: 4.1295e-05
# Epoch 47/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.1004e-05 - mean_squared_error: 4.1004e-05
# Epoch 48/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.9502e-05 - mean_squared_error: 3.9502e-05
# Epoch 49/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.6621e-05 - mean_squared_error: 3.6621e-05
# Epoch 50/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.6591e-05 - mean_squared_error: 3.6591e-05 - val_loss: 2.4420e-04 - val_mean_squared_error: 2.4420e-04
# Epoch 51/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.5461e-05 - mean_squared_error: 3.5461e-05
# Epoch 52/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.2413e-05 - mean_squared_error: 3.2413e-05
# Epoch 53/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.4937e-05 - mean_squared_error: 3.4937e-05
# Epoch 54/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.5423e-05 - mean_squared_error: 3.5423e-05
# Epoch 55/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.4416e-05 - mean_squared_error: 3.4416e-05 - val_loss: 1.2729e-04 - val_mean_squared_error: 1.2729e-04
# Epoch 56/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.2111e-05 - mean_squared_error: 4.2111e-05
# Epoch 57/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.3531e-05 - mean_squared_error: 3.3531e-05
# Epoch 58/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.1038e-05 - mean_squared_error: 3.1038e-05
# Epoch 59/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.2241e-05 - mean_squared_error: 3.2241e-05
# Epoch 60/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.2214e-05 - mean_squared_error: 3.2214e-05 - val_loss: 2.0321e-04 - val_mean_squared_error: 2.0321e-04
# Epoch 61/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.1871e-05 - mean_squared_error: 3.1871e-05
# Epoch 62/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.9147e-05 - mean_squared_error: 2.9147e-05
# Epoch 63/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.9508e-05 - mean_squared_error: 2.9508e-05
# Epoch 64/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.3122e-05 - mean_squared_error: 3.3122e-05
# Epoch 65/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.9477e-05 - mean_squared_error: 2.9477e-05 - val_loss: 1.5496e-04 - val_mean_squared_error: 1.5496e-04
# Epoch 66/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.8639e-05 - mean_squared_error: 2.8639e-05
# Epoch 67/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.8895e-05 - mean_squared_error: 2.8895e-05
# Epoch 68/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.8399e-05 - mean_squared_error: 2.8399e-05
# Epoch 69/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.6201e-05 - mean_squared_error: 2.6201e-05
# Epoch 70/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.8956e-05 - mean_squared_error: 2.8956e-05 - val_loss: 1.9477e-04 - val_mean_squared_error: 1.9477e-04
# Epoch 71/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.9325e-05 - mean_squared_error: 2.9325e-05
# Epoch 72/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.5475e-05 - mean_squared_error: 2.5475e-05
# Epoch 73/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.6013e-05 - mean_squared_error: 2.6013e-05
# Epoch 74/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4843e-05 - mean_squared_error: 2.4843e-05
# Epoch 75/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.6180e-05 - mean_squared_error: 2.6180e-05 - val_loss: 2.1945e-04 - val_mean_squared_error: 2.1945e-04
# Epoch 76/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.7092e-05 - mean_squared_error: 2.7092e-05
# Epoch 77/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4825e-05 - mean_squared_error: 2.4825e-05
# Epoch 78/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.6913e-05 - mean_squared_error: 2.6913e-05
# Epoch 79/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4818e-05 - mean_squared_error: 2.4818e-05
# Epoch 80/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4926e-05 - mean_squared_error: 2.4926e-05 - val_loss: 1.5956e-04 - val_mean_squared_error: 1.5956e-04
# Epoch 81/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4456e-05 - mean_squared_error: 2.4456e-05
# Epoch 82/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4446e-05 - mean_squared_error: 2.4446e-05
# Epoch 83/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.2693e-05 - mean_squared_error: 2.2693e-05
# Epoch 84/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.3436e-05 - mean_squared_error: 2.3436e-05
# Epoch 85/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4898e-05 - mean_squared_error: 2.4898e-05 - val_loss: 1.9765e-04 - val_mean_squared_error: 1.9765e-04
# Epoch 86/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.2756e-05 - mean_squared_error: 2.2756e-05
# Epoch 87/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.3901e-05 - mean_squared_error: 2.3901e-05
# Epoch 88/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.1906e-05 - mean_squared_error: 2.1906e-05
# Epoch 89/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.2433e-05 - mean_squared_error: 2.2433e-05
# Epoch 90/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.2631e-05 - mean_squared_error: 2.2631e-05 - val_loss: 1.4629e-04 - val_mean_squared_error: 1.4629e-04
# Epoch 91/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.2109e-05 - mean_squared_error: 2.2109e-05
# Epoch 92/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.0946e-05 - mean_squared_error: 2.0946e-05
# Epoch 93/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.2518e-05 - mean_squared_error: 2.2518e-05
# Epoch 94/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.0906e-05 - mean_squared_error: 2.0906e-05
# Epoch 95/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.2292e-05 - mean_squared_error: 2.2292e-05 - val_loss: 1.2266e-04 - val_mean_squared_error: 1.2266e-04
# Epoch 96/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.2258e-05 - mean_squared_error: 2.2258e-05
# Epoch 97/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.0751e-05 - mean_squared_error: 2.0751e-05
# Epoch 98/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.1945e-05 - mean_squared_error: 2.1945e-05
# Epoch 99/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.1685e-05 - mean_squared_error: 2.1685e-05
# Epoch 100/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.1159e-05 - mean_squared_error: 2.1159e-05 - val_loss: 2.2448e-04 - val_mean_squared_error: 2.2448e-04

# %%
# Plot training and validation loss
plt.plot(np.arange(num_epochs), history.history['loss'], label='Train Loss')
plt.plot(np.linspace(0, num_epochs, num=int(np.ceil(num_epochs/5))), history.history['val_loss'], label='Test Loss', marker='o')
plt.ylim(0, 0.0005)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Test Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Check the fit of the model

# %%
nn.evaluate(X,  normalize_output(y), verbose=2)
# Out:
# 859/859 - 0s - loss: 1.6200e-04 - mean_squared_error: 1.6200e-04 - 318ms/epoch - 370us/step
# [0.0001620016701053828, 0.0001620016701053828]

# %% [markdown]
# ## Checking against the original data

# %%
output_variable = "avg_diff"
predictions_normed = nn.predict(X)
# Rescale the predictions
predictions = predictions_normed * (y.max() - y.min()) + y.min()
y_pred = predictions
y_diff = y - y_pred
print(
    f"The mean abs diff between y and y_pred is {np.absolute(y_diff).mean()}."
)
print(f"The max diff between y and y_pred is {y_diff.max()}.")
print(f"The min diff between y and y_pred is {y_diff.min()}.")
# Out:
# 859/859 [==============================] - 0s 386us/step
# The mean abs diff between y and y_pred is 51.9875446529598.
# The max diff between y and y_pred is 93.52646967687951.
# The min diff between y and y_pred is -300.40598546320916.

# %%
normalization_layer = nn.get_layer('normalization')
mean = normalization_layer.mean.numpy()
variance = normalization_layer.variance.numpy()
print("Mean: ", mean)
print("Std dev: ", variance**(1/2))
# Out:
# Mean:  [[54.73748     8.35946     8.381766    1.8990896   1.8962128   0.53320134]]
# Std dev:  [[5.95917    4.787876   4.805051   1.4172095  1.4169149  0.39561728]]

# %% [markdown]
# # Check closeness to runs used in Silver Linings Book
#
# There are a number of runs included in the Silver Linings book that we want to hit **extremely** closely. We can check how close the surrogate model is to these runs.

# %%
# Load model
X_book = X[-472:, :]
y_book = y[-472:, :]

# predict using the model
y_book_pred_norm = nn.predict(X_book)
y_book_pred = y_book_pred_norm * (y.max() - y.min()) + y.min()
y_book_diff = y_book - y_book_pred
print(
    f"The mean abs diff between y_book_pred and y_book " +
    f"is {np.absolute(y_book_diff).mean()}."
)
print(f"The max diff between y_book_pred and y_book is {y_book_diff.max()}.")
print(f"The min diff between y_book_pred and y_book is {y_book_diff.min()}.")
# Out:
# 15/15 [==============================] - 0s 589us/step
# The mean abs diff between y_book_pred and y_book is 49.03615845387859.
# The max diff between y_book_pred and y_book is 25.126978509398725.
# The min diff between y_book_pred and y_book is -141.690645743083.
